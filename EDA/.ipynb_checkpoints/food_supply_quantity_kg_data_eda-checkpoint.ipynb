# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
path = "../data/Food_Supply_Quantity_kg_Data.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan               0.0014       0.1973           9.4341
# 1              Albania               1.6719       0.1357          18.7684
# 2              Algeria               0.2711       0.0282           9.6334
# 3               Angola               5.8087       0.0560           4.9278
# 4  Antigua and Barbuda               3.5764       0.0087          16.6613
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   24.8097  0.2099         0.0350
# 1                      0.0                    5.7817  0.5815         0.2126
# 2                      0.0                   13.6816  0.5277         0.2416
# 3                      0.0                    9.1085  0.0587         1.7707
# 4                      0.0                    5.9960  0.2274         4.1489
#
#    Fruits - Excluding Wine    Meat  ...  Vegetables  Vegetal Products  \
# 0                   5.3495  1.2020  ...      6.7642           40.5645
# 1                   6.7861  1.8845  ...     11.7753           31.2304
# 2                   6.3801  1.1305  ...     11.6484           40.3651
# 3                   6.0005  2.0571  ...      2.3041           45.0722
# 4                  10.7451  5.6888  ...      5.4495           33.3233
#
#    Obesity  Undernourished  Confirmed    Deaths  Recovered    Active  \
# 0      4.5            29.8   0.053472  0.000938   0.004929  0.047605
# 1     22.3             6.2   0.043597  0.001190   0.032820  0.009587
# 2     26.6             3.9   0.023393  0.001629   0.015475  0.006289
# 3      6.8              25   0.000290  0.000013   0.000076  0.000200
# 4     19.1             NaN   0.026804  0.003093   0.020619  0.003093
#
#    Population  Unit (all except Population)
# 0  38042000.0                             %
# 1   2858000.0                             %
# 2  43406000.0                             %
# 3  31427000.0                             %
# 4     97000.0                             %
#
# [5 rows x 32 columns]

# %%
for col in df.columns: 
    print(col)
# Out:
# Country
# Alcoholic Beverages
# Animal fats
# Animal Products
# Aquatic Products, Other
# Cereals - Excluding Beer
# Eggs
# Fish, Seafood
# Fruits - Excluding Wine
# Meat
# Milk - Excluding Butter
# Miscellaneous
# Offals
# Oilcrops
# Pulses
# Spices
# Starchy Roots
# Stimulants
# Sugar & Sweeteners
# Sugar Crops
# Treenuts
# Vegetable Oils
# Vegetables
# Vegetal Products
# Obesity
# Undernourished
# Confirmed
# Deaths
# Recovered
# Active
# Population
# Unit (all except Population)

# %%
df['Rec_Rate'] = df[['Confirmed', 'Active', 'Recovered']].apply(lambda x: (x['Recovered']/(x['Confirmed']-x['Active']))*100, axis=1)
df = df.sort_values(by=['Rec_Rate'], ascending=False)

# %%
df['Total Confirmed'] = df[['Confirmed', 'Population']].apply(lambda row: (row['Confirmed']/100)*row['Population'], axis=1)

# %%
#top ranked countries with highest recovery rate with cases more than  
df['Country'].loc[df['Total Confirmed']>= 100000].head(10)
# Out:
# 133                  Saudi Arabia
# 29                          Chile
# 126            Russian Federation
# 154                        Turkey
# 56                        Germany
# 68                          India
# 70     Iran (Islamic Republic of)
# 120                          Peru
# 20                         Brazil
# 100                        Mexico
# Name: Country, dtype: object

# %%
df[['Country', 'Rec_Rate']].loc[df['Total Confirmed']>= 100000].head(4)
# Out:
#                 Country   Rec_Rate
# 133        Saudi Arabia  99.031675
# 29                Chile  98.508931
# 126  Russian Federation  97.479354
# 154              Turkey  96.711084

# %%
df_filtered_top = df[df["Country"].isin(["Saudi Arabia", "Chile", "Russian Federation", "Turkey"])]
df_filtered_top = df_filtered_top.sort_values(by=['Rec_Rate'], ascending=False)
df_filtered_top
# Out:
#                 Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 133        Saudi Arabia               0.0000       0.3917          12.9962
# 29                Chile               4.9690       0.1782          15.0394
# 126  Russian Federation               3.7425       0.2486          16.1525
# 154              Turkey               0.6474       0.1459          12.3156
#
#      Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 133                   0.0000                   16.3284  0.6003         1.0369
# 29                    0.0155                   10.8579  0.7757         0.8711
# 126                   0.0023                    8.2803  0.9029         1.1312
# 154                   0.0000                    9.7080  0.3956         0.2582
#
#      Fruits - Excluding Wine    Meat  ...  Obesity  Undernourished  Confirmed  \
# 133                   7.0413  4.9529  ...     35.0             7.1   0.297837
# 29                    3.9109  6.1492  ...     28.8             2.7   0.702099
# 126                   3.1620  4.3180  ...     25.7            <2.5   0.318319
# 154                   6.8321  2.0694  ...     32.2            <2.5   0.205953
#
#        Deaths  Recovered    Active   Population  Unit (all except Population)  \
# 133  0.002081   0.212803  0.082953   34218000.0                             %
# 29   0.008568   0.566023  0.127508   19107000.0                             %
# 126  0.003988   0.154209  0.160123  146731000.0                             %
# 154  0.005680   0.167019  0.033255   82607000.0                             %
#
#       Rec_Rate  Total Confirmed
# 133  99.031675         101914.0
# 29   98.508931         134150.0
# 126  97.479354         467073.0
# 154  96.711084         170132.0
#
# [4 rows x 34 columns]

# %%
df_filtered_top_food = df_filtered_top.iloc[:,1:24]
df_filtered_top_food.sum(axis = 1, skipna = True)
# Out:
# 133    100.0001
# 29     100.0001
# 126     99.9999
# 154    100.0001
# dtype: float64

# %%
df_filtered_top['Max_Value'] = df_filtered_top_food.max(axis=1)

df_filtered_top['Max_Value']
# Out:
# 133    37.0038
# 29     34.9584
# 126    33.8472
# 154    37.6836
# Name: Max_Value, dtype: float64

# %%
df_filtered_top['Max_Value_Column'] = df_filtered_top_food.idxmax(axis=1)
 
df_filtered_top['Max_Value_Column']
# Out:
# 133    Vegetal Products
# 29     Vegetal Products
# 126    Vegetal Products
# 154    Vegetal Products
# Name: Max_Value_Column, dtype: object

# %%
df_filtered_top['Min_Value'] = df_filtered_top_food.min(axis=1)

df_filtered_top['Min_Value']
# Out:
# 133    0.0
# 29     0.0
# 126    0.0
# 154    0.0
# Name: Min_Value, dtype: float64

# %%
df_filtered_top['Min_Value_Column'] = df_filtered_top_food.idxmin(axis=1)
 
df_filtered_top['Min_Value_Column']
# Out:
# 133        Alcoholic Beverages
# 29                 Sugar Crops
# 126                Sugar Crops
# 154    Aquatic Products, Other
# Name: Min_Value_Column, dtype: object

# %%
df[['Country', 'Rec_Rate']].loc[df['Total Confirmed']>= 100000].tail(4)
# Out:
#                       Country   Rec_Rate
# 74                      Italy  83.028097
# 161  United States of America  79.948813
# 51                     France  70.876657
# 159            United Kingdom   2.959583

# %%
df_filtered_bottom = df[df["Country"].isin(["Italy", "United States of America", "France", "United Kingdom"])]
df_filtered_bottom = df_filtered_bottom.sort_values(by=['Rec_Rate'], ascending=True)
df_filtered_bottom
# Out:
#                       Country  Alcoholic Beverages  Animal fats  \
# 159            United Kingdom               5.2632       0.2754
# 51                     France               4.1631       0.7907
# 161  United States of America               4.8647       0.1681
# 74                      Italy               3.1892       0.2834
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 159          18.8798                   0.0006                    6.5412
# 51           21.7097                   0.0011                    6.9951
# 161          21.2352                   0.0020                    5.5048
# 74           19.0329                   0.0005                    8.5417
#
#        Eggs  Fish, Seafood  Fruits - Excluding Wine    Meat  ...  Obesity  \
# 159  0.6210         1.0911                   4.9551  4.4181  ...     29.5
# 51   0.6110         1.8214                   4.8780  4.4005  ...     23.2
# 161  0.7860         1.1287                   4.5432  6.2645  ...     37.3
# 74   0.6247         1.5816                   6.0207  4.2963  ...     22.9
#
#      Undernourished  Confirmed    Deaths  Recovered    Active   Population  \
# 159            <2.5   0.430358  0.060786   0.001854  0.367718   66833000.0
# 51             <2.5   0.294756  0.044973   0.109450  0.140332   64834000.0
# 161            <2.5   0.590109  0.033575   0.153839  0.397687  329153000.0
# 74             <2.5   0.389424  0.056175   0.274815  0.058434   60345000.0
#
#      Unit (all except Population)   Rec_Rate  Total Confirmed
# 159                             %   2.959583         287621.0
# 51                              %  70.876657         191102.0
# 161                             %  79.948813        1942363.0
# 74                              %  83.028097         234998.0
#
# [4 rows x 34 columns]

# %%
df_filtered_bottom_food = df_filtered_bottom.iloc[:,1:24]
df_filtered_bottom_food.sum(axis = 1, skipna = True)
# Out:
# 159     99.9998
# 51     100.0000
# 161    100.0000
# 74      99.9998
# dtype: float64

# %%
df_filtered_bottom['Max_Value'] = df_filtered_bottom_food.max(axis=1)

df_filtered_bottom['Max_Value']
# Out:
# 159    31.1116
# 51     28.2903
# 161    28.7587
# 74     30.9671
# Name: Max_Value, dtype: float64

# %%
df_filtered_bottom['Max_Value_Column'] = df_filtered_bottom_food.idxmax(axis=1)
 
df_filtered_bottom['Max_Value_Column']
# Out:
# 159    Vegetal Products
# 51     Vegetal Products
# 161    Vegetal Products
# 74     Vegetal Products
# Name: Max_Value_Column, dtype: object

# %%
df_filtered_bottom['Min_Value'] = df_filtered_bottom_food.min(axis=1)

df_filtered_bottom['Min_Value']
# Out:
# 159    0.0
# 51     0.0
# 161    0.0
# 74     0.0
# Name: Min_Value, dtype: float64

# %%
df_filtered_bottom['Min_Value_Column'] = df_filtered_bottom_food.idxmin(axis=1)
 
df_filtered_bottom['Min_Value_Column']
# Out:
# 159      Sugar Crops
# 51       Sugar Crops
# 161    Miscellaneous
# 74       Sugar Crops
# Name: Min_Value_Column, dtype: object

# %%
top_countries = df[['Country', 'Rec_Rate']].loc[df['Total Confirmed']>= 50000].head(10)
top_countries
# Out:
#                         Country   Rec_Rate
# 133                Saudi Arabia  99.031675
# 29                        Chile  98.508931
# 126          Russian Federation  97.479354
# 154                      Turkey  96.711084
# 56                      Germany  95.118291
# 68                        India  94.500782
# 30                        China  94.483300
# 117                    Pakistan  94.355316
# 70   Iran (Islamic Republic of)  94.194069
# 120                        Peru  94.039309

# %%
bottom_countries = df[['Country', 'Rec_Rate']].loc[df['Total Confirmed']>= 50000].tail(10)
bottom_countries
# Out:
#                       Country   Rec_Rate
# 11                 Bangladesh  93.996349
# 20                     Brazil  88.622284
# 26                     Canada  87.407277
# 100                    Mexico  85.945996
# 141                     Spain  84.713146
# 74                      Italy  83.028097
# 161  United States of America  79.948813
# 51                     France  70.876657
# 14                    Belgium  62.933632
# 159            United Kingdom   2.959583

# %%
top_bottom_countries = pd.concat([top_countries, bottom_countries], axis=0)
top_bottom_countries
# Out:
#                         Country   Rec_Rate
# 133                Saudi Arabia  99.031675
# 29                        Chile  98.508931
# 126          Russian Federation  97.479354
# 154                      Turkey  96.711084
# 56                      Germany  95.118291
# 68                        India  94.500782
# 30                        China  94.483300
# 117                    Pakistan  94.355316
# 70   Iran (Islamic Republic of)  94.194069
# 120                        Peru  94.039309
# 11                   Bangladesh  93.996349
# 20                       Brazil  88.622284
# 26                       Canada  87.407277
# 100                      Mexico  85.945996
# 141                       Spain  84.713146
# 74                        Italy  83.028097
# 161    United States of America  79.948813
# 51                       France  70.876657
# 14                      Belgium  62.933632
# 159              United Kingdom   2.959583

# %%
df_filtered_10 = df[df["Country"].isin(top_bottom_countries["Country"])]
df_filtered_10 = df_filtered_10.sort_values(by=['Rec_Rate'], ascending=False)
df_filtered_10
# Out:
#                         Country  Alcoholic Beverages  Animal fats  \
# 133                Saudi Arabia               0.0000       0.3917
# 29                        Chile               4.9690       0.1782
# 126          Russian Federation               3.7425       0.2486
# 154                      Turkey               0.6474       0.1459
# 56                      Germany               6.7714       0.6715
# 68                        India               0.1959       0.0028
# 30                        China               2.3224       0.0866
# 117                    Pakistan               0.0085       0.0969
# 70   Iran (Islamic Republic of)               0.0007       0.5369
# 120                        Peru               3.8623       0.0316
# 11                   Bangladesh               0.0031       0.0156
# 20                       Brazil               4.3629       0.2803
# 26                       Canada               4.8441       0.8084
# 100                      Mexico               4.4105       0.1672
# 141                       Spain               5.3152       0.2357
# 74                        Italy               3.1892       0.2834
# 161    United States of America               4.8647       0.1681
# 51                       France               4.1631       0.7907
# 14                      Belgium               5.3730       0.8559
# 159              United Kingdom               5.2632       0.2754
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 133          12.9962                   0.0000                   16.3284
# 29           15.0394                   0.0155                   10.8579
# 126          16.1525                   0.0023                    8.2803
# 154          12.3156                   0.0000                    9.7080
# 56           20.8485                   0.0011                    6.0363
# 68           11.3357                   0.0000                   17.3821
# 30           13.4240                   0.0542                    8.9298
# 117          22.2758                   0.0011                   14.6224
# 70            7.9295                   0.0020                   14.0141
# 120           8.6638                   0.0014                   11.8140
# 11            5.1926                   0.0000                   29.8045
# 20           17.3470                   0.0000                    8.4292
# 26           16.0365                   0.0060                    6.4236
# 100          15.1527                   0.0201                   11.4325
# 141          18.3382                   0.0011                    6.0548
# 74           19.0329                   0.0005                    8.5417
# 161          21.2352                   0.0020                    5.5048
# 51           21.7097                   0.0011                    6.9951
# 14           17.7279                   0.0010                    6.6704
# 159          18.8798                   0.0006                    6.5412
#
#        Eggs  Fish, Seafood  Fruits - Excluding Wine    Meat  ...  Obesity  \
# 133  0.6003         1.0369                   7.0413  4.9529  ...     35.0
# 29   0.7757         0.8711                   3.9109  6.1492  ...     28.8
# 126  0.9029         1.1312                   3.1620  4.3180  ...     25.7
# 154  0.3956         0.2582                   6.8321  2.0694  ...     32.2
# 56   0.5947         0.6758                   3.6131  4.6524  ...     25.7
# 68   0.3061         0.6499                   5.4333  0.3560  ...      3.8
# 30   1.2059         3.3435                   4.2451  6.0732  ...      6.6
# 117  0.3577         0.1831                   2.4099  1.7957  ...      7.8
# 70   0.4916         0.7813                   7.9235  2.3965  ...     25.5
# 120  0.6431         1.7993                   8.5783  1.7540  ...     19.1
# 11   0.2957         2.5221                   2.8655  0.4191  ...      3.4
# 20   0.5042         0.5899                   6.0936  6.4784  ...     22.3
# 26   0.7668         1.2148                   5.0692  4.4707  ...     31.3
# 100  1.2967         0.9656                   7.6794  4.3561  ...     28.4
# 141  0.7321         2.2646                   4.8332  5.3456  ...     27.1
# 74   0.6247         1.5816                   6.0207  4.2963  ...     22.9
# 161  0.7860         1.1287                   4.5432  6.2645  ...     37.3
# 51   0.6110         1.8214                   4.8780  4.4005  ...     23.2
# 14   0.6487         1.1325                   4.1623  3.2370  ...     24.5
# 159  0.6210         1.0911                   4.9551  4.4181  ...     29.5
#
#      Undernourished  Confirmed    Deaths  Recovered    Active    Population  \
# 133             7.1   0.297837  0.002081   0.212803  0.082953  3.421800e+07
# 29              2.7   0.702099  0.008568   0.566023  0.127508  1.910700e+07
# 126            <2.5   0.318319  0.003988   0.154209  0.160123  1.467310e+08
# 154            <2.5   0.205953  0.005680   0.167019  0.033255  8.260700e+07
# 56             <2.5   0.223526  0.010451   0.203639  0.009436  8.310000e+07
# 68             14.5   0.018499  0.000518   0.008898  0.009083  1.391885e+09
# 30              8.5   0.006022  0.000332   0.005682  0.000009  1.398030e+09
# 117            20.3   0.045687  0.000924   0.015453  0.029310  2.165650e+08
# 70              4.9   0.204728  0.009869   0.160109  0.034750  8.391100e+07
# 120             9.7   0.618341  0.017196   0.271291  0.329854  3.178100e+07
# 11             14.7   0.040185  0.000543   0.008495  0.031147  1.636670e+08
# 20             <2.5   0.330460  0.017415   0.135647  0.177398  2.093320e+08
# 26             <2.5   0.259744  0.021054   0.146139  0.092551  3.741300e+07
# 100             3.6   0.092515  0.010823   0.066185  0.015508  1.265770e+08
# 141            <2.5   0.513139  0.057647   0.319453  0.136040  4.707300e+07
# 74             <2.5   0.389424  0.056175   0.274815  0.058434  6.034500e+07
# 161            <2.5   0.590109  0.033575   0.153839  0.397687  3.291530e+08
# 51             <2.5   0.294756  0.044973   0.109450  0.140332  6.483400e+07
# 14             <2.5   0.516896  0.083741   0.142180  0.290976  1.145800e+07
# 159            <2.5   0.430358  0.060786   0.001854  0.367718  6.683300e+07
#
#      Unit (all except Population)   Rec_Rate  Total Confirmed
# 133                             %  99.031675         101914.0
# 29                              %  98.508931         134150.0
# 126                             %  97.479354         467073.0
# 154                             %  96.711084         170132.0
# 56                              %  95.118291         185750.0
# 68                              %  94.500782         257486.0
# 30                              %  94.483300          84191.0
# 117                             %  94.355316          98943.0
# 70                              %  94.194069         171789.0
# 120                             %  94.039309         196515.0
# 11                              %  93.996349          65769.0
# 20                              %  88.622284         691758.0
# 26                              %  87.407277          97178.0
# 100                             %  85.945996         117103.0
# 141                             %  84.713146         241550.0
# 74                              %  83.028097         234998.0
# 161                             %  79.948813        1942363.0
# 51                              %  70.876657         191102.0
# 14                              %  62.933632          59226.0
# 159                             %   2.959583         287621.0
#
# [20 rows x 34 columns]

# %%
df_filtered_10_food = df_filtered_10.iloc[:,1:24]
df_filtered_10_food.sum(axis = 1, skipna = True)
# Out:
# 133    100.0001
# 29     100.0001
# 126     99.9999
# 154    100.0001
# 56     100.0000
# 68      99.9999
# 30      99.9998
# 117    100.0001
# 70     100.0000
# 120    100.0000
# 11      99.9999
# 20      99.9999
# 26      99.9999
# 100     99.9995
# 141    100.0001
# 74      99.9998
# 161    100.0000
# 51     100.0000
# 14     100.0001
# 159     99.9998
# dtype: float64

# %%
df_filtered_10['Max_Value'] = df_filtered_10_food.max(axis=1)

df_filtered_10['Max_Value']
# Out:
# 133    37.0038
# 29     34.9584
# 126    33.8472
# 154    37.6836
# 56     29.1443
# 68     38.6568
# 30     36.5744
# 117    27.7226
# 70     42.0701
# 120    41.3344
# 11     44.8033
# 20     32.6537
# 26     33.9551
# 100    34.8456
# 141    31.6581
# 74     30.9671
# 161    28.7587
# 51     28.2903
# 14     32.2637
# 159    31.1116
# Name: Max_Value, dtype: float64

# %%
df_filtered_10['Max_Value_Column'] = df_filtered_10_food.idxmax(axis=1)
 
df_filtered_10['Max_Value_Column']
# Out:
# 133    Vegetal Products
# 29     Vegetal Products
# 126    Vegetal Products
# 154    Vegetal Products
# 56     Vegetal Products
# 68     Vegetal Products
# 30     Vegetal Products
# 117    Vegetal Products
# 70     Vegetal Products
# 120    Vegetal Products
# 11     Vegetal Products
# 20     Vegetal Products
# 26     Vegetal Products
# 100    Vegetal Products
# 141    Vegetal Products
# 74     Vegetal Products
# 161    Vegetal Products
# 51     Vegetal Products
# 14     Vegetal Products
# 159    Vegetal Products
# Name: Max_Value_Column, dtype: object

# %%
df_filtered_10['Min_Value'] = df_filtered_10_food.min(axis=1)

df_filtered_10['Min_Value']
# Out:
# 133    0.0000
# 29     0.0000
# 126    0.0000
# 154    0.0000
# 56     0.0000
# 68     0.0000
# 30     0.0253
# 117    0.0011
# 70     0.0000
# 120    0.0000
# 11     0.0000
# 20     0.0000
# 26     0.0000
# 100    0.0000
# 141    0.0000
# 74     0.0000
# 161    0.0000
# 51     0.0000
# 14     0.0000
# 159    0.0000
# Name: Min_Value, dtype: float64

# %%
df_filtered_10['Min_Value_Column'] = df_filtered_10_food.idxmin(axis=1)
 
df_filtered_10['Min_Value_Column']
# Out:
# 133        Alcoholic Beverages
# 29                 Sugar Crops
# 126                Sugar Crops
# 154    Aquatic Products, Other
# 56               Miscellaneous
# 68     Aquatic Products, Other
# 30                 Sugar Crops
# 117    Aquatic Products, Other
# 70                 Sugar Crops
# 120                Sugar Crops
# 11     Aquatic Products, Other
# 20     Aquatic Products, Other
# 26                 Sugar Crops
# 100                Sugar Crops
# 141              Miscellaneous
# 74                 Sugar Crops
# 161              Miscellaneous
# 51                 Sugar Crops
# 14               Miscellaneous
# 159                Sugar Crops
# Name: Min_Value_Column, dtype: object

# %%
df_filtered_10.plot.bar(x='Country', y='Rec_Rate', color = ['r', 'g', 'y', 'k'])

# %%
df_filtered_10['Rec_Rate'] = df_filtered_10['Rec_Rate'].astype(float)
df_filtered_10['Max_Value'] = df_filtered_10['Max_Value'].astype(float)
df_filtered_10['Min_Value'] = df_filtered_10['Min_Value'].astype(float)


df_filtered_10
# Out:
#                         Country  Alcoholic Beverages  Animal fats  \
# 133                Saudi Arabia               0.0000       0.3917
# 29                        Chile               4.9690       0.1782
# 126          Russian Federation               3.7425       0.2486
# 154                      Turkey               0.6474       0.1459
# 56                      Germany               6.7714       0.6715
# 68                        India               0.1959       0.0028
# 30                        China               2.3224       0.0866
# 117                    Pakistan               0.0085       0.0969
# 70   Iran (Islamic Republic of)               0.0007       0.5369
# 120                        Peru               3.8623       0.0316
# 11                   Bangladesh               0.0031       0.0156
# 20                       Brazil               4.3629       0.2803
# 26                       Canada               4.8441       0.8084
# 100                      Mexico               4.4105       0.1672
# 141                       Spain               5.3152       0.2357
# 74                        Italy               3.1892       0.2834
# 161    United States of America               4.8647       0.1681
# 51                       France               4.1631       0.7907
# 14                      Belgium               5.3730       0.8559
# 159              United Kingdom               5.2632       0.2754
#
#      Animal Products  Aquatic Products, Other  Cereals - Excluding Beer  \
# 133          12.9962                   0.0000                   16.3284
# 29           15.0394                   0.0155                   10.8579
# 126          16.1525                   0.0023                    8.2803
# 154          12.3156                   0.0000                    9.7080
# 56           20.8485                   0.0011                    6.0363
# 68           11.3357                   0.0000                   17.3821
# 30           13.4240                   0.0542                    8.9298
# 117          22.2758                   0.0011                   14.6224
# 70            7.9295                   0.0020                   14.0141
# 120           8.6638                   0.0014                   11.8140
# 11            5.1926                   0.0000                   29.8045
# 20           17.3470                   0.0000                    8.4292
# 26           16.0365                   0.0060                    6.4236
# 100          15.1527                   0.0201                   11.4325
# 141          18.3382                   0.0011                    6.0548
# 74           19.0329                   0.0005                    8.5417
# 161          21.2352                   0.0020                    5.5048
# 51           21.7097                   0.0011                    6.9951
# 14           17.7279                   0.0010                    6.6704
# 159          18.8798                   0.0006                    6.5412
#
#        Eggs  Fish, Seafood  Fruits - Excluding Wine    Meat  ...  Recovered  \
# 133  0.6003         1.0369                   7.0413  4.9529  ...   0.212803
# 29   0.7757         0.8711                   3.9109  6.1492  ...   0.566023
# 126  0.9029         1.1312                   3.1620  4.3180  ...   0.154209
# 154  0.3956         0.2582                   6.8321  2.0694  ...   0.167019
# 56   0.5947         0.6758                   3.6131  4.6524  ...   0.203639
# 68   0.3061         0.6499                   5.4333  0.3560  ...   0.008898
# 30   1.2059         3.3435                   4.2451  6.0732  ...   0.005682
# 117  0.3577         0.1831                   2.4099  1.7957  ...   0.015453
# 70   0.4916         0.7813                   7.9235  2.3965  ...   0.160109
# 120  0.6431         1.7993                   8.5783  1.7540  ...   0.271291
# 11   0.2957         2.5221                   2.8655  0.4191  ...   0.008495
# 20   0.5042         0.5899                   6.0936  6.4784  ...   0.135647
# 26   0.7668         1.2148                   5.0692  4.4707  ...   0.146139
# 100  1.2967         0.9656                   7.6794  4.3561  ...   0.066185
# 141  0.7321         2.2646                   4.8332  5.3456  ...   0.319453
# 74   0.6247         1.5816                   6.0207  4.2963  ...   0.274815
# 161  0.7860         1.1287                   4.5432  6.2645  ...   0.153839
# 51   0.6110         1.8214                   4.8780  4.4005  ...   0.109450
# 14   0.6487         1.1325                   4.1623  3.2370  ...   0.142180
# 159  0.6210         1.0911                   4.9551  4.4181  ...   0.001854
#
#        Active    Population  Unit (all except Population)   Rec_Rate  \
# 133  0.082953  3.421800e+07                             %  99.031675
# 29   0.127508  1.910700e+07                             %  98.508931
# 126  0.160123  1.467310e+08                             %  97.479354
# 154  0.033255  8.260700e+07                             %  96.711084
# 56   0.009436  8.310000e+07                             %  95.118291
# 68   0.009083  1.391885e+09                             %  94.500782
# 30   0.000009  1.398030e+09                             %  94.483300
# 117  0.029310  2.165650e+08                             %  94.355316
# 70   0.034750  8.391100e+07                             %  94.194069
# 120  0.329854  3.178100e+07                             %  94.039309
# 11   0.031147  1.636670e+08                             %  93.996349
# 20   0.177398  2.093320e+08                             %  88.622284
# 26   0.092551  3.741300e+07                             %  87.407277
# 100  0.015508  1.265770e+08                             %  85.945996
# 141  0.136040  4.707300e+07                             %  84.713146
# 74   0.058434  6.034500e+07                             %  83.028097
# 161  0.397687  3.291530e+08                             %  79.948813
# 51   0.140332  6.483400e+07                             %  70.876657
# 14   0.290976  1.145800e+07                             %  62.933632
# 159  0.367718  6.683300e+07                             %   2.959583
#
#      Total Confirmed  Max_Value  Max_Value_Column  Min_Value  \
# 133         101914.0    37.0038  Vegetal Products     0.0000
# 29          134150.0    34.9584  Vegetal Products     0.0000
# 126         467073.0    33.8472  Vegetal Products     0.0000
# 154         170132.0    37.6836  Vegetal Products     0.0000
# 56          185750.0    29.1443  Vegetal Products     0.0000
# 68          257486.0    38.6568  Vegetal Products     0.0000
# 30           84191.0    36.5744  Vegetal Products     0.0253
# 117          98943.0    27.7226  Vegetal Products     0.0011
# 70          171789.0    42.0701  Vegetal Products     0.0000
# 120         196515.0    41.3344  Vegetal Products     0.0000
# 11           65769.0    44.8033  Vegetal Products     0.0000
# 20          691758.0    32.6537  Vegetal Products     0.0000
# 26           97178.0    33.9551  Vegetal Products     0.0000
# 100         117103.0    34.8456  Vegetal Products     0.0000
# 141         241550.0    31.6581  Vegetal Products     0.0000
# 74          234998.0    30.9671  Vegetal Products     0.0000
# 161        1942363.0    28.7587  Vegetal Products     0.0000
# 51          191102.0    28.2903  Vegetal Products     0.0000
# 14           59226.0    32.2637  Vegetal Products     0.0000
# 159         287621.0    31.1116  Vegetal Products     0.0000
#
#             Min_Value_Column
# 133      Alcoholic Beverages
# 29               Sugar Crops
# 126              Sugar Crops
# 154  Aquatic Products, Other
# 56             Miscellaneous
# 68   Aquatic Products, Other
# 30               Sugar Crops
# 117  Aquatic Products, Other
# 70               Sugar Crops
# 120              Sugar Crops
# 11   Aquatic Products, Other
# 20   Aquatic Products, Other
# 26               Sugar Crops
# 100              Sugar Crops
# 141            Miscellaneous
# 74               Sugar Crops
# 161            Miscellaneous
# 51               Sugar Crops
# 14             Miscellaneous
# 159              Sugar Crops
#
# [20 rows x 38 columns]

# %%
ax = df_filtered_10.plot(x="Country", y=["Rec_Rate", "Max_Value"], kind="bar", figsize=(15,5))
for p in ax.patches:
    ax.annotate(str(float("{:.2f}".format(p.get_height()))), (p.get_x() * 1.005, p.get_height() * 1.01))

# %%
df_filtered_10.groupby(['Country','Max_Value_Column']).size().unstack().plot(kind='bar',stacked=True, figsize=(15,5))

# %%
ax2 = df_filtered_10.plot(x="Country", y=["Rec_Rate", "Min_Value"], kind="bar", figsize=(15,5))
for p in ax2.patches:
    ax2.annotate(str(float("{:.2f}".format(p.get_height()))), (p.get_x() * 1.005, p.get_height() * 1.01))

# %%
df_filtered_10.groupby(['Country','Min_Value_Column']).size().unstack().plot(kind='bar',stacked=True, figsize=(15,5))
