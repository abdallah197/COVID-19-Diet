# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path_kg = "../data/Food_Supply_Quantity_kg_Data.csv"
path_kcal = "../data/Food_Supply_kcal_Data.csv"
path_fat = "../data/Fat_Supply_Quantity_Data.csv"
path_protein = "../data/Protein_Supply_Quantity_Data.csv"
df_kg = pd.read_csv(path_kg)
df_kcal = pd.read_csv(path_kcal)
df_fat = pd.read_csv(path_fat)
df_protein = pd.read_csv(path_protein)

# %%
df_kg.head()
# Out:
#                Country  Alcoholic Beverages  Animal fats  Animal Products  \
# 0          Afghanistan               0.0014       0.1973           9.4341
# 1              Albania               1.6719       0.1357          18.7684
# 2              Algeria               0.2711       0.0282           9.6334
# 3               Angola               5.8087       0.0560           4.9278
# 4  Antigua and Barbuda               3.5764       0.0087          16.6613
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   24.8097  0.2099         0.0350
# 1                      0.0                    5.7817  0.5815         0.2126
# 2                      0.0                   13.6816  0.5277         0.2416
# 3                      0.0                    9.1085  0.0587         1.7707
# 4                      0.0                    5.9960  0.2274         4.1489
#
# ...

# %%
df_kcal.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           4.7774       0.8504
# 1              Albania               0.9120          16.0930       1.0591
# 2              Algeria               0.0896           6.0326       0.1941
# 3               Angola               1.9388           4.6927       0.2644
# 4  Antigua and Barbuda               2.3041          15.3672       1.5429
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   37.1186  0.1501         0.0000
# 1                      0.0                   16.2107  0.8091         0.1471
# 2                      0.0                   25.0112  0.4181         0.1195
# 3                      0.0                   18.3521  0.0441         0.8372
# 4                      0.0                   13.7215  0.2057         1.7280
#
# ...

# %%
df_fat.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0          21.6397       6.2224
# 1              Albania                  0.0          32.0002       3.4172
# 2              Algeria                  0.0          14.4175       0.8972
# 3               Angola                  0.0          15.3041       1.3130
# 4  Antigua and Barbuda                  0.0          27.7033       4.6686
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 4                      0.0                    3.2153  0.3872         1.5263
#
# ...

# %%
df_protein.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
# ...

# %%
for col in df_kg.columns: 
    print(col)
# Out:
# Country
# Alcoholic Beverages
# Animal fats
# Animal Products
# Aquatic Products, Other
# Cereals - Excluding Beer
# Eggs
# Fish, Seafood
# Fruits - Excluding Wine
# Meat
# Milk - Excluding Butter
# Miscellaneous
# Offals
# Oilcrops
# Pulses
# Spices
# Starchy Roots
# Stimulants
# Sugar & Sweeteners
# Sugar Crops
# Treenuts
# Vegetable Oils
# Vegetables
# Vegetal Products
# Obesity
# Undernourished
# Confirmed
# Deaths
# Recovered
# Active
# Population
# Unit (all except Population)

# %%
def prepare_rec_rate_and_total_confirmed(df):
    df['Rec_Rate'] = df[['Confirmed', 'Active', 'Recovered']].apply(lambda x: (x['Recovered']/(x['Confirmed']-x['Active']))*100, axis=1)
    df = df.sort_values(by=['Rec_Rate'], ascending=False)
    
    df['Total Confirmed'] = df[['Confirmed', 'Population']].apply(lambda row: (row['Confirmed']/100)*row['Population'], axis=1)
    
    return df

# %%
df_kg = prepare_rec_rate_and_total_confirmed(df_kg)
df_kcal = prepare_rec_rate_and_total_confirmed(df_kcal)
df_fat = prepare_rec_rate_and_total_confirmed(df_fat)
df_protein = prepare_rec_rate_and_total_confirmed(df_protein)

# %%
# Top ranked countries with highest recovery rate with cases more than  
df_kg['Country'].loc[df_kg['Total Confirmed']>= 50000].head(16)
# Out:
# 133                  Saudi Arabia
# 29                          Chile
# 126            Russian Federation
# 154                        Turkey
# 56                        Germany
# 68                          India
# 30                          China
# 117                      Pakistan
# 70     Iran (Islamic Republic of)
# 120                          Peru
# 11                     Bangladesh
# 20                         Brazil
# 26                         Canada
# 100                        Mexico
# 141                         Spain
# 74                          Italy
# Name: Country, dtype: object

# %%
df_kg_filtered = df_kg[df_kg["Country"].isin(["Russian Federation", "France", "India", "Spain"])]
df_kcal_filtered = df_kcal[df_kcal["Country"].isin(["Russian Federation", "France", "India", "Spain"])]
df_fat_filtered = df_fat[df_fat["Country"].isin(["Russian Federation", "France", "India", "Spain"])]
df_protein_filtered = df_protein[df_protein["Country"].isin(["Russian Federation", "France", "India", "Spain"])]

# %%
def prepare_data_for_each_country(country):
    
    df_kg_country = df_kg[df_kg["Country"] == country]
    df_kcal_country = df_kcal[df_kcal["Country"] == country]
    df_fat_country = df_fat[df_fat["Country"] == country]
    df_protein_country = df_protein[df_protein["Country"] == country]
    
    return df_kg_country, df_kcal_country, df_fat_country, df_protein_country

# %%
df_kg_Russia, df_kcal_Russia, df_fat_Russia, df_protein_Russia = prepare_data_for_each_country("Russian Federation")

df_kg_India, df_kcal_India, df_fat_India, df_protein_India = prepare_data_for_each_country("India")

df_kg_Spain, df_kcal_Spain, df_fat_Spain, df_protein_Spain = prepare_data_for_each_country("Spain")

df_kg_France, df_kcal_France, df_fat_France, df_protein_France = prepare_data_for_each_country("France")

# %%
def prepare_data_for_each_country_for_plotting(df_kg, df_kcal, df_fat, df_protein):

    # Prepare data for plotting for Russia Federation
    df_column_names=list(df)[1:24]
    df_kg_percentages=df_kg.iloc[:,1:24]
    df_kcal_percentages=df_kcal.iloc[:,1:24]
    df_fat_percentages=df_fat.iloc[:,1:24]
    df_protein_percentages=df_protein.iloc[:,1:24]
    
    return df_column_names, df_kg_percentages, df_kcal_percentages, df_fat_percentages, df_protein_percentages

# %%
df_Russia_column_names, df_kg_Russia_percentages, df_kcal_Russia_percentages, df_fat_Russia_percentages, df_protein_Russia_percentages = prepare_data_for_each_country_for_plotting(df_kg_Russia, df_kcal_Russia, df_fat_Russia, df_protein_Russia)

df_India_column_names, df_kg_India_percentages, df_kcal_India_percentages, df_fat_India_percentages, df_protein_India_percentages = prepare_data_for_each_country_for_plotting(df_kg_India, df_kcal_India, df_fat_India, df_protein_India)

df_Spain_column_names, df_kg_Spain_percentages, df_kcal_Spain_percentages, df_fat_Spain_percentages, df_protein_Spain_percentages = prepare_data_for_each_country_for_plotting(df_kg_Spain, df_kcal_Spain, df_fat_Spain, df_protein_Spain)

df_France_column_names, df_kg_France_percentages, df_kcal_France_percentages, df_fat_France_percentages, df_protein_France_percentages = prepare_data_for_each_country_for_plotting(df_kg_France, df_kcal_France, df_fat_France, df_protein_France)

# %%
# Import libraries for plotting and Data Visualization
import numpy as np
from pandas.api.types import CategoricalDtype
from plotnine import *
from plotnine.data import mpg
import matplotlib.colors as colors
# %matplotlib inline

import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %%
# Setting global parameters for matplotlib to be applied to all plots

print(plt.rcParams.get('figure.figsize'))
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size
plt.rcParams.update({'font.size': 12})

colors_list = list(colors._colors_full_map.values())
colors_list_filtered = colors_list[:23]
# Out:
# [6.0, 4.0]

# %%
def draw_scatter_plot(df, title):

    return (ggplot(df)         # defining what data to use
     + aes(x='Country', y = 'Rec_Rate', color='Country')    # defining what variable to use
     + geom_point(size=7)
     + labs(title=title, x='Countries', y='Recovery Rate')
     + geom_text(aes(x="Country", y="Rec_Rate", label='Rec_Rate'),
         stat='identity',
         nudge_y=2.3,
         format_string='{:.1f}% ')
    )

# %%
def draw_pie_chart(df_percentages, df_column_names, title):
    print("Draw a Pie Chart")

    #explsion
    explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)

    #color
    from random import randint
    color = []
    n = 23
    for i in range(n):
        color.append('#%06X' % randint(0, 0xFFFFFF))

    plt.pie(df_percentages, labels=df_column_names, labeldistance=1.05, autopct='%1.1f%%', startangle=10, pctdistance=0.85, explode = explode, colors=colors_list_filtered)
    #draw circle
    centre_circle = plt.Circle((0,0),0.70,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    # Equal aspect ratio ensures that pie is drawn as a circle
    plt.axis('equal', radius=1800)
    plt.legend(df_column_names, title="Food Categories",
              loc="right", bbox_to_anchor=(1.5, 0.5))
    plt.title(title, pad=20, fontsize= 20)
    plt.figure(figsize=[50, 50])
    plt.tight_layout()
    plt.show()

# %%
def draw_bar_chart(df_percentages, df_column_names, title):

    df_percentages_list = df_percentages.values.tolist()
    df_percentages_list_flattened = list(np.concatenate(df_percentages_list).flat)

    demo = pd.DataFrame({"x-axis": df_column_names,
                         "y-axis": df_percentages_list_flattened})

    return ggplot(data=demo) +\
    geom_bar(mapping=aes(x="x-axis", y="y-axis", fill='x-axis'), stat="identity", size=20) +\
    coord_flip() +\
    labs(title=title, x='Food Categories', y='Percentages') +\
    geom_text(
         aes(x="x-axis", y="y-axis", label='y-axis'),
         stat='identity',
         nudge_y=2.3,
         format_string='{:.1f}% '
    )

# %%
df_kg_filtered_scatter_plot = draw_scatter_plot(df_kg_filtered, "Recovery Rate for each Country")
df_kg_filtered_scatter_plot
# Out:
# <ggplot: (312386491)>

# %%
df_kg_Russia_percentages_pie_chart = draw_pie_chart(df_kg_Russia_percentages, df_Russia_column_names, "Percentage of Food Supply in KG in (Russia)")
df_kg_France_percentages_pie_chart = draw_pie_chart(df_kg_France_percentages, df_France_column_names, "Percentage of Food Supply in KG in (France)")
print(df_kg_Russia_percentages_pie_chart)
print(df_kg_France_percentages_pie_chart)
# Out:
# Draw a Pie Chart
# Draw a Pie Chart
# None
# None

# %%
df_kg_Russia_percentages_bar_plot = draw_bar_chart(df_kg_Russia_percentages, df_Russia_column_names, "Percentage of Food Supply Consumed in KG in (Russia)")
df_kg_France_percentages_bar_plot = draw_bar_chart(df_kg_France_percentages, df_France_column_names, "Percentage of Food Supply in KG in (France)")
print(df_kg_Russia_percentages_bar_plot)
print(df_kg_France_percentages_bar_plot)
# Out:
# <ggplot: (311051499)>
# <ggplot: (307959393)>

# %%
df_fat_Russia_percentages_pie_chart = draw_pie_chart(df_fat_Russia_percentages, df_Russia_column_names, "Percentage of Fat Consumed in (Russia)")
df_fat_France_percentages_pie_chart = draw_pie_chart(df_fat_France_percentages, df_France_column_names, "Percentage of Fat Consumed in (France)")
print(df_fat_Russia_percentages_pie_chart)
print(df_fat_France_percentages_pie_chart)
# Out:
# Draw a Pie Chart
# Draw a Pie Chart
# None
# None

# %%
df_fat_Russia_percentages_bar_plot = draw_bar_chart(df_fat_Russia_percentages, df_Russia_column_names, "Percentage of Fat Consumed in (Russia)")
df_fat_France_percentages_bar_plot = draw_bar_chart(df_fat_France_percentages, df_France_column_names, "Percentage of Fat Consumed in (France)")
print(df_fat_Russia_percentages_bar_plot)
print(df_fat_France_percentages_bar_plot)
# Out:
# <ggplot: (311747548)>
# <ggplot: (311346429)>

# %%
df_protein_Russia_percentages_pie_chart = draw_pie_chart(df_protein_Russia_percentages, df_Russia_column_names, "Percentage of Protein Consumed in (Russia)")
df_protein_France_percentages_pie_chart = draw_pie_chart(df_protein_France_percentages, df_France_column_names, "Percentage of Protein Consumed in (France)")
print(df_protein_Russia_percentages_pie_chart)
print(df_protein_France_percentages_pie_chart)
# Out:
# Draw a Pie Chart
# Draw a Pie Chart
# None
# None

# %%
df_protein_Russia_percentages_bar_plot = draw_bar_chart(df_protein_Russia_percentages, df_Russia_column_names, "Percentage of Protein Consumed in (Russia)")
df_protein_France_percentages_bar_plot = draw_bar_chart(df_protein_France_percentages, df_France_column_names, "Percentage of Protein Consumed in (France)")
print(df_protein_Russia_percentages_bar_plot)
print(df_protein_France_percentages_bar_plot)
# Out:
# <ggplot: (310461639)>
# <ggplot: (311946662)>

# %%
df_kcal_Russia_percentages_pie_chart = draw_pie_chart(df_kcal_Russia_percentages, df_Russia_column_names, "Percentage of Energy Consumed in Kcal in (Russia)")
df_kcal_France_percentages_pie_chart = draw_pie_chart(df_kcal_France_percentages, df_France_column_names, "Percentage of Energy Consumed in Kcal in (France)")
print(df_kcal_Russia_percentages_pie_chart)
print(df_kcal_France_percentages_pie_chart)
# Out:
# Draw a Pie Chart
# Draw a Pie Chart
# None
# None

# %%
df_kcal_Russia_percentages_bar_plot = draw_bar_chart(df_kcal_Russia_percentages, df_Russia_column_names, "Percentage of Energy Consumed in Kcal in (Russia)")
df_kcal_France_percentages_bar_plot = draw_bar_chart(df_kcal_France_percentages, df_France_column_names, "Percentage of Energy Consumed in Kcal in (France)")
print(df_kcal_Russia_percentages_bar_plot)
print(df_kcal_France_percentages_bar_plot)
# Out:
# <ggplot: (310040028)>
# <ggplot: (307732414)>

# %%
import seaborn as sns
sns.set(style="ticks", color_codes=True)

# %%
def correlation(df, title):
    sns.set(font_scale=1)
    # Compute the correlation matrix
    corr = df.corr()

    # Generate a mask for the upper triangle
    mask = np.triu(np.ones_like(corr, dtype=np.bool))

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Generate a custom diverging colormap
    # cmap = sns.diverging_palette(220, 10, as_cmap=True)
    cmap = sns.diverging_palette(20, 220, n=200)
    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, vmin=-1, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})
    ax.set_title(title, pad=20, fontsize= 20)
#     ax.set_xticklabels(
#         ax.get_xticklabels(),
#         rotation=45,
#         horizontalalignment='right'
#     );

# %%
def correlation_values(df, title):

    df_correlation = df.corr()
    cmap = sns.diverging_palette(20, 220, n=200)
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))
    sns.heatmap(corr[['Rec_Rate']].sort_values(by=['Rec_Rate'],ascending=False),
                vmin=-1,
                vmax=1, center=0,
                cmap=cmap,
                annot=True,linewidths=1.5, cbar_kws={"shrink": .5})
    ax.set_title(title, pad=20, fontsize= 20)

# %%
def plot_variable_against_others(df, title, x_vars):
    sns.set(font_scale=1.5)
    g = sns.pairplot(df, y_vars=["Rec_Rate"], x_vars=x_vars, hue="Country", 
                     height=3, plot_kws={"s": 150})
    g.fig.set_size_inches(20,5)
    g.fig.suptitle(title, y=1.08) # y= some height>1

# %%
correlation(df_kg_filtered, "'Percentage of Food Supply in KG' - Correlation of between all 4 Countries (Russia), (France), (Spain), (India)")

correlation_values(df_kg_filtered, "'Percentage of Food Supply in KG' - Correlation between Recovery Rate and other variables")

# %%
plot_variable_against_others(df_kg_filtered, "'Percentage of Food Supply in KG' - Comparing Recovery rate against most correlated food categories", 
                             ["Starchy Roots", "Vegetables", "Cereals - Excluding Beer", "Vegetal Products", "Oilcrops"])

plot_variable_against_others(df_kg_filtered, "'Percentage of Food Supply in KG' - Comparing Recovery rate against least correlated food categories", 
                             ["Stimulants", "Treenuts", "Miscellaneous", "Fruits - Excluding Wine", "Animal Products"])

# %%
correlation(df_fat_filtered, "'Percentage of Fat Consumed' - Correlation of between all 4 Countries (Russia), (France), (Spain), (India)")

correlation_values(df_fat_filtered, "'Percentage of Fat Consumed' - Correlation between Recovery Rate and other variables")

# %%
plot_variable_against_others(df_fat_filtered, "'Percentage of Fat Consumed' - Comparing Recovery rate against most correlated food categories", 
                             ["Starchy Roots", "Vegetables", "Cereals - Excluding Beer", "Vegetal Products", "Oilcrops"])

plot_variable_against_others(df_fat_filtered, "'Percentage of Fat Consumed' - Comparing Recovery rate against least correlated food categories", 
                             ["Stimulants", "Treenuts", "Miscellaneous", "Fruits - Excluding Wine", "Animal Products"])

# %%
correlation(df_protein_filtered, "'Percentage of Protein Consumed' - Correlation of between all 4 Countries (Russia), (France), (Spain), (India)")

correlation_values(df_protein_filtered, "'Percentage of Protein Consumed' - Correlation between Recovery Rate and other variables")

# %%
plot_variable_against_others(df_protein_filtered, "'Percentage of Protein Consumed' - Comparing Recovery rate against most correlated food categories", 
                             ["Starchy Roots", "Vegetables", "Cereals - Excluding Beer", "Vegetal Products", "Oilcrops"])

plot_variable_against_others(df_protein_filtered, "'Percentage of Protein Consumed' - Comparing Recovery rate against least correlated food categories", 
                             ["Stimulants", "Treenuts", "Miscellaneous", "Fruits - Excluding Wine", "Animal Products"])

# %%
correlation(df_kcal_filtered, "'Percentage of Energy Consumed in kcal' - Correlation of between all 4 Countries (Russia), (France), (Spain), (India)")

correlation_values(df_kcal_filtered, "'Percentage of Energy Consumed in kcal' - Correlation between Recovery Rate and other variables")

# %%
plot_variable_against_others(df_kcal_filtered, "'Percentage of Energy Consumed in kcal' - Comparing Recovery rate against most correlated food categories", 
                             ["Starchy Roots", "Vegetables", "Cereals - Excluding Beer", "Vegetal Products", "Oilcrops"])

plot_variable_against_others(df_kcal_filtered, "'Percentage of Energy Consumed in kcal' - Comparing Recovery rate against least correlated food categories", 
                             ["Stimulants", "Treenuts", "Miscellaneous", "Fruits - Excluding Wine", "Animal Products"])
